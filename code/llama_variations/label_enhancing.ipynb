# %% [markdown]
# # Label Enhancing for VLM-Generated Descriptions
# Within this Jupyter Notebook, LLaMa 3.2b, by *Meta* is utilized.
# It generates three different variations from the original VLM generated Descriptions

# %%
import pandas as pd
import time
from ollama import chat
from ollama import ChatResponse

# %% [markdown]
# ### Cleaning CSVs
# The AudioSet and AudioCaps dataset will be reorganized for clarity into how the LLM will input responses back

# %%
audioset_molmo_desc_file = 'audioset_description.csv'
audioset_description_df = pd.read_csv(audioset_molmo_desc_file)
audioset_description_df = audioset_description_df.drop_duplicates()
audioset_description_df.reset_index(drop=True, inplace=True)
audioset_description_df.shape
# Out:
# (7584, 2)

# %%
audiocaps_molmo_desc_file = 'audiocap-descriptionNEW.csv'
audiocaps_description_df = pd.read_csv(audiocaps_molmo_desc_file)
audiocaps_description_df = audiocaps_description_df.drop_duplicates()
audiocaps_description_df.reset_index(drop=True, inplace=True)
audiocaps_description_df.shape
# Out:
# (1614, 2)

# %%
# Places a separate column for the YouTube IDs for each point through regex
if 'YTID' not in audioset_description_df.columns:
    audioset_description_df.insert(
        0,
        'YTID', 
        audioset_description_df['Image Name'].str.extract(r'\[([\w-]+)\]_cut_')
    )
if 'YTID' not in audiocaps_description_df.columns:
    audiocaps_description_df.insert(
        0,
        'YTID', 
        audiocaps_description_df['Image Name'].str.extract(r'\[([\w-]+)\]_cut_')
    )
display(audioset_description_df)
display(audiocaps_description_df)
# Out:
#              YTID                                         Image Name  \
# 0     _qodustNrME  STREET FIGHTER VS ASURAï¼Ÿ Asura's Wrath DLC T...
# 1     ieZVo7W3BQ4  VI Truck Show Ciudad de Torrelavega, desfile d...
# 2     FXlPUGUw9UU  Insonnia Musica Rilassante x il sonno Dormire,...
# 3     wMXiOt2HHUw  iRobot Roomba 560 limpiando en casa [wMXiOt2HH...
# 4     C4YMjmJ7tt4  Bhagwant Mann - Full Speed - Part - 2 WwWKOOKD...
# ...           ...                                                ...
# 7579  2v1rSA4FqlM  Human powered washing machine [2v1rSA4FqlM]_cu...
# 7580  ZbJD8pWYsk0  Liza Soberano Slap Enrique Gil [ZbJD8pWYsk0]_c...
# 7581  3Kb4RHaZpxo  Sound Effect - Telephone [3Kb4RHaZpxo]_cut_0.jpeg
# 7582  3oqo61gK5Co  National Cash Register Class 1900  motorized [...
# 7583  PvewGmGO06Q  samsung whistle ringtone [PvewGmGO06Q]_cut_0.jpeg
#
#                                             Description
# 0      Picture a dramatic battle scene unfolding in ...
# 1      Imagine the distant rumble of a truck's engin...
# 2      Imagine a tranquil nighttime scene by a seren...
# 3      Imagine a serene, sun-drenched living room ba...
# 4      Imagine the distant hum of traffic, punctuate...
# ...                                                 ...
# 7579   The image, if translated into sound, might ev...
# 7580   Imagine a lively, intimate setting where two ...
# 7581   Picture a dimly lit room, shrouded in an air ...
# 7582   Imagine a bustling, vintage recording studio ...
# 7583   Imagine a bustling urban street at night, fil...
#
# [7584 rows x 3 columns]
#              YTID                                         Image Name  \
# 0     1VSLSGXlG1s  65888_Metal Gear Solid 4 Big Boss Emblem Act I...
# 1     Y2KCoO8C8R8  21313_ã€é›»å­è­¦ç¬›ã€‘E233ç³»6000ç•ªå° [Y2K...
# 2     7HUQ_NtyY3k  19744_There's a fish at the door [7HUQ_NtyY3k]...
# 3     vJrc42EJIyg  21489_Totally Free Sound Effects #25 - Faucet ...
# 4     jqtqV0BQ8GU  81484_Spore Creature Creator - Mud skipper â§¸...
# ...           ...                                                ...
# 1609  we8NP0EKyZQ  83637_25 lb Little Giant Power Hammer Demo [we...
# 1610  3Hza-oEdi7E  13489_Red Staffordshire Bull Terrier & Cat sta...
# 1611  45FElpwPRnc  8033_Bath Sink Overflow ï¼š Part 7â€”artisan s...
# 1612  3Hz5urV9T_o   13489_1930 model a horn [3Hz5urV9T_o]_cut_0.jpeg
# 1613  522VGTixFy8  14800_How to Install Spray Foam Insulationï¼š ...
#
#                                             Description
# 0      Imagine the distant rumble of heavy machinery...
# 1      Imagine the gentle hum of an electric train a...
# 2      Imagine a quiet, contemplative moment capture...
# 3      Imagine a bustling kitchen filled with the si...
# 4      Imagine a whimsical, cartoon-like forest scen...
# ...                                                 ...
# 1609   Imagine the rhythmic clanking of metal on met...
# 1610   Imagine a serene winter scene viewed through ...
# 1611   Imagine the soft, rhythmic sound of water bei...
# 1612   Imagine the distant rumble of a powerful engi...
# 1613   The image might sound like this:\n\nThe dista...
#
# [1614 rows x 3 columns]

# %% [markdown]
# ### Running LLaMa3.2b
# We utilize the API for LLaMa3.2b using the ollama library.
# The three variations for prompting the LLM is also listed below

# %%
from ollama import chat
from ollama import ChatResponse

def llama3_2(prompt, description):
    if pd.isna(description):  # Handle missing values
        return None
    response: ChatResponse = chat(model='llama3.2', messages=[
        {'role': 'system','content': prompt,},
        {'role': 'user', 'content': description,},
    ])
    return response.message.content

# %%
# The same variations will be used for both sets to be consistent
variation_concise_label = "Use the words in the label provided that are associated with audio to only output descriptive three-word descriptions of those audio words keeping their relevance super close to the context"
variation_hypothetical_mood_label = "Analyzing the given label, create a hypothetical mood, that is super relevant to the content in the text, with words in the label that are associated to auditory sensations"
variation_rephrase_label = "Rephrase the contents in the label into something new and descriptive while maintaining extreme relevance to the content inside of the label, using the words that are associated with sounds"

# %%
import os
# The new csv with the three variations will be renewed every 50 datapoints
output_folder = 'checkpoints_for_variation'
audioset_output_file = os.path.join(output_folder, 'audioset_descriptions_vars.csv')
audiocaps_output_file = os.path.join(output_folder, 'audiocaps_descriptions_vars.csv')

os.makedirs(output_folder, exist_ok=True)

checkpoint_interval = 50
processed_rows = 0

# %%
# For updated AudioSet Descriptions Generated from Molmo
start = time.time()
for i in range(len(audioset_description_df)):
    # Skip all processed datapoints
    if 'Variation_Concise_Label' in audioset_description_df.columns and pd.notna(audioset_description_df.at[i, 'Variation_Concise_Label']):
        continue
    
    # Three Variations
    description = audioset_description_df.at[i, 'Description']
    audioset_description_df.at[i, 'Variation_Concise_Label'] = llama3_2(variation_concise_label, description)
    audioset_description_df.at[i, 'Variation_Hypothetical_Mood_Label'] = llama3_2(variation_hypothetical_mood_label, description)
    audioset_description_df.at[i, 'Variation_Rephrase_Label'] = llama3_2(variation_rephrase_label, description)
    processed_rows += 1

    # Update csv after every 50 points
    if processed_rows % checkpoint_interval == 0:
        print(f"Saving checkpoint after {processed_rows} processed rows...")
        audioset_description_df.to_csv(audioset_output_file, index=False)
        print(f"Saved to {audioset_output_file}.")

# The entire CSV is saved after
audioset_description_df.to_csv(audioset_output_file, index=False)
elapsed = time.time() - start
print(f"Time taken: {elapsed:.2f} seconds")
# Out:
# Saving checkpoint after 50 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 100 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 150 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 200 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 250 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 300 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 350 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 400 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 450 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 500 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 550 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 600 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 650 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 700 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 750 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 800 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 850 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 900 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 950 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1000 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1050 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1100 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1150 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1200 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1250 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1300 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1350 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1400 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1450 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1500 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1550 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1600 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1650 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1700 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1750 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1800 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1850 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1900 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 1950 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2000 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2050 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2100 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2150 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2200 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2250 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2300 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2350 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2400 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2450 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2500 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2550 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2600 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2650 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2700 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2750 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2800 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2850 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2900 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 2950 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3000 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3050 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3100 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3150 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3200 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3250 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3300 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3350 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3400 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3450 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3500 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3550 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3600 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3650 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3700 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3750 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3800 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3850 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3900 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 3950 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 4000 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 4050 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 4100 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 4150 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 4200 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 4250 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 4300 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Saving checkpoint after 4350 processed rows...
# Saved to checkpoints_for_variation/audioset_descriptions_vars.csv.
# Time taken: 30672.32 seconds

# %%
# For updated AudioCaps Descriptions Generated from Molmo for Validation
start = time.time()
for i in range(len(audiocaps_description_df)):
    # Skip all processed datapoints
    if 'Variation_Concise_Label' in audiocaps_description_df.columns and pd.notna(audiocaps_description_df.at[i, 'Variation_Concise_Label']):
        continue
    
    # Three Variations
    description = audiocaps_description_df.at[i, 'Description']
    audiocaps_description_df.at[i, 'Variation_Concise_Label'] = llama3_2(variation_concise_label, description)
    audiocaps_description_df.at[i, 'Variation_Hypothetical_Mood_Label'] = llama3_2(variation_hypothetical_mood_label, description)
    audiocaps_description_df.at[i, 'Variation_Rephrase_Label'] = llama3_2(variation_rephrase_label, description)
    processed_rows += 1

    # Update csv at every 100 points
    if processed_rows % checkpoint_interval == 0:
        print(f"Saving checkpoint after {processed_rows} processed rows...")
        audiocaps_description_df.to_csv(audiocaps_output_file, index=False)
        print(f"Saved to {audiocaps_output_file}.")

# The entire CSV is saved after
audiocaps_description_df.to_csv(audiocaps_output_file, index=False)
elapsed = time.time() - start
print(f"Time taken for 'Variation_Concise_Label': {elapsed:.2f} seconds")
# Out:
# Saving checkpoint after 4400 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4450 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4500 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4550 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4600 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4650 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4700 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4750 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4800 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4850 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4900 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 4950 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5000 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5050 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5100 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5150 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5200 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5250 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5300 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5350 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5400 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5450 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5500 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5550 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5600 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5650 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5700 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5750 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5800 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5850 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5900 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Saving checkpoint after 5950 processed rows...
# Saved to checkpoints_for_variation/audiocaps_descriptions_vars.csv.
# Time taken for 'Variation_Concise_Label': 11315.80 seconds

# %%
display(audioset_description_df)
display(audiocaps_description_df)
# Out:
#              YTID                                         Image Name  \
# 0     _qodustNrME  STREET FIGHTER VS ASURAï¼Ÿ Asura's Wrath DLC T...
# 1     ieZVo7W3BQ4  VI Truck Show Ciudad de Torrelavega, desfile d...
# 2     FXlPUGUw9UU  Insonnia Musica Rilassante x il sonno Dormire,...
# 3     wMXiOt2HHUw  iRobot Roomba 560 limpiando en casa [wMXiOt2HH...
# 4     C4YMjmJ7tt4  Bhagwant Mann - Full Speed - Part - 2 WwWKOOKD...
# ...           ...                                                ...
# 7579  2v1rSA4FqlM  Human powered washing machine [2v1rSA4FqlM]_cu...
# 7580  ZbJD8pWYsk0  Liza Soberano Slap Enrique Gil [ZbJD8pWYsk0]_c...
# 7581  3Kb4RHaZpxo  Sound Effect - Telephone [3Kb4RHaZpxo]_cut_0.jpeg
# 7582  3oqo61gK5Co  National Cash Register Class 1900  motorized [...
# 7583  PvewGmGO06Q  samsung whistle ringtone [PvewGmGO06Q]_cut_0.jpeg
#
#                                             Description  \
# 0      Picture a dramatic battle scene unfolding in ...
# 1      Imagine the distant rumble of a truck's engin...
# 2      Imagine a tranquil nighttime scene by a seren...
# 3      Imagine a serene, sun-drenched living room ba...
# 4      Imagine the distant hum of traffic, punctuate...
# ...                                                 ...
# 7579   The image, if translated into sound, might ev...
# 7580   Imagine a lively, intimate setting where two ...
# 7581   Picture a dimly lit room, shrouded in an air ...
# 7582   Imagine a bustling, vintage recording studio ...
# 7583   Imagine a bustling urban street at night, fil...
#
#                                 Variation_Concise_Label  \
# 0     Here are three-word descriptions for each audi...
# 1     Here are the descriptive three-word descriptio...
# 2     Here are three-word descriptive outputs for ea...
# 3     Here are three-word descriptions for audio-rel...
# 4     Here are the descriptive three-word descriptio...
# ...                                                 ...
# 7579  Here are the audio-related words with three-wo...
# 7580  Here are three-word descriptions for the audio...
# 7581  Here are three-word descriptions for some audi...
# 7582  Here are three-word descriptions for audio-rel...
# 7583  Here are the descriptive three-word audio desc...
#
#                       Variation_Hypothetical_Mood_Label  \
# 0     **Dramatic Battle Scene**\n\nAudiophile's Mood...
# 1     Here's a hypothetical mood label with words as...
# 2     Here's a hypothetical mood label associated wi...
# 3     Here's a hypothetical label that captures the ...
# 4     "Hush, harmony"\n\nThis label captures the ser...
# ...                                                 ...
# 7579  Here is the revised label with a hypothetical ...
# 7580  The hypothetical label for this scenario could...
# 7581  **Mood:** High-Stakes Action Thriller\n\n**Lab...
# 7582  "Electric Dreams and Vintage Vibes"\n\nImagine...
# 7583  "Midnight Melodies in the City"\n\nThis label ...
#
#                                Variation_Rephrase_Label
# 0     **"Echoes of Conflict: A Symphony of Steel and...
# 1     The label begins with a low-frequency vibratio...
# 2     Here's a rephrased version of the content usin...
# 3     Here's a rephrased version of the label conten...
# 4     The soothing serenade of urban life unfolds li...
# ...                                                 ...
# 7579  "Vibrate with creativity," the image whispers,...
# 7580  "Snap into focus: the vibrant cadence of human...
# 7581  Imagine being enveloped by an ominous silence,...
# 7582  "Capturing the Vibrations: A Symphony of Sound...
# 7583  "Vibrant Nightlife"\n\n*Sound of sizzling sere...
#
# [7584 rows x 6 columns]
#              YTID                                         Image Name  \
# 0     1VSLSGXlG1s  65888_Metal Gear Solid 4 Big Boss Emblem Act I...
# 1     Y2KCoO8C8R8  21313_ã€é›»å­è­¦ç¬›ã€‘E233ç³»6000ç•ªå° [Y2K...
# 2     7HUQ_NtyY3k  19744_There's a fish at the door [7HUQ_NtyY3k]...
# 3     vJrc42EJIyg  21489_Totally Free Sound Effects #25 - Faucet ...
# 4     jqtqV0BQ8GU  81484_Spore Creature Creator - Mud skipper â§¸...
# ...           ...                                                ...
# 1609  we8NP0EKyZQ  83637_25 lb Little Giant Power Hammer Demo [we...
# 1610  3Hza-oEdi7E  13489_Red Staffordshire Bull Terrier & Cat sta...
# 1611  45FElpwPRnc  8033_Bath Sink Overflow ï¼š Part 7â€”artisan s...
# 1612  3Hz5urV9T_o   13489_1930 model a horn [3Hz5urV9T_o]_cut_0.jpeg
# 1613  522VGTixFy8  14800_How to Install Spray Foam Insulationï¼š ...
#
#                                             Description  \
# 0      Imagine the distant rumble of heavy machinery...
# 1      Imagine the gentle hum of an electric train a...
# 2      Imagine a quiet, contemplative moment capture...
# 3      Imagine a bustling kitchen filled with the si...
# 4      Imagine a whimsical, cartoon-like forest scen...
# ...                                                 ...
# 1609   Imagine the rhythmic clanking of metal on met...
# 1610   Imagine a serene winter scene viewed through ...
# 1611   Imagine the soft, rhythmic sound of water bei...
# 1612   Imagine the distant rumble of a powerful engi...
# 1613   The image might sound like this:\n\nThe dista...
#
#                                 Variation_Concise_Label  \
# 0     Here are the descriptive three-word descriptio...
# 1     Here are three-word descriptions for each audi...
# 2     Here are three-word descriptions for each audi...
# 3     Here are three-word descriptions for some of t...
# 4     Here are three-word audio descriptions:\n\n1. ...
# ...                                                 ...
# 1609  Here are three-word descriptions associated wi...
# 1610  Here are three-word descriptions for the audio...
# 1611  Here are the descriptive three-word descriptio...
# 1612  Here are three-word descriptions for each audi...
# 1613  Here are three-word descriptions for each audi...
#
#                       Variation_Hypothetical_Mood_Label  \
# 0     **Mood: "Crisis Point"**\n\nThe label for this...
# 1     Here is a hypothetical mood label associated w...
# 2     "Whispers in Twilight"\n\n(Soft piano melody p...
# 3     Here's a hypothetical label that matches this ...
# 4     **Whimsical Woodland Soundscape**\n\n**Label: ...
# ...                                                 ...
# 1609  Here's a hypothetical mood label with words as...
# 1610  Based on the serene winter scene described, I ...
# 1611  **Label: "Whispers from the Clay Studio"**\n\n...
# 1612  Here's a hypothetical label that captures the ...
# 1613  **Mood:** "Immersive Workbench"\n\n**Color Pal...
#
#                                Variation_Rephrase_Label
# 0     Imagine a stark, pulsing hum, like the steady ...
# 1     "Embark on a journey through the symphony of m...
# 2     "Echoes in Silence"\n\nThe whispers of the pas...
# 3     "Harmony of the Senses: A Symphony of Flavors"...
# 4     Imagine being enveloped in an enchanting sound...
# ...                                                 ...
# 1609  Imagine the symphony of sonic sensations as a ...
# 1610  Here's a rephrased version of the content in a...
# 1611  **Ethereal Cadence: A Symphony of Clay**\n\nIm...
# 1612  **"Ignition"**\n\nThe soft purr of a vintage e...
# 1613  "Unveiling the Hidden Harmony"\n\nA solitary n...
#
# [1614 rows x 6 columns]
